# %%
print('Data Augmentation using ImageDataGenerator')
# Out:
# Data Augmentation using ImageDataGenerator

# %%
import tensorflow as tf
# Out:
# 2022-12-28 12:40:48.038948: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-28 12:40:48.119295: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-12-28 12:40:48.122450: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-28 12:40:48.122458: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-28 12:40:48.140005: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-12-28 12:40:48.537671: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-28 12:40:48.537702: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-28 12:40:48.537706: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from tensorflow.keras.preprocessing import image

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img=image.load_img('badhon.jpg')
plt.imshow(img)

# %%
datagen=image.ImageDataGenerator()
datagen

# %%
#convert numpy array
data=image.img_to_array(img)
# expand the dimension
samples=np.expand_dims(data,0)

# %% [markdown]
# ## Horizontal and vertical shift

# %%
shift_datagen=image.ImageDataGenerator(width_shift_range=[-100,100])
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <keras.preprocessing.image.NumpyArrayIterator object at 0x7f776168c730>

# %%
shift_datagen=image.ImageDataGenerator(height_shift_range=0.5)
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <keras.preprocessing.image.NumpyArrayIterator object at 0x7f775fd6ce20>

# %% [markdown]
# ## Horizontal and vertical flip augmentation

# %%
flip_datagen=image.ImageDataGenerator(horizontal_flip=True)
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <keras.preprocessing.image.NumpyArrayIterator object at 0x7f775d8f4ee0>

# %%
flip_datagen=image.ImageDataGenerator(vertical_flip=True)
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <keras.preprocessing.image.NumpyArrayIterator object at 0x7f775d74bf40>

# %% [markdown]
# ## Random rotation augmentation

# %%
rotation_datagen=image.ImageDataGenerator(rotation_range=90)
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <keras.preprocessing.image.NumpyArrayIterator object at 0x7f775d297cd0>

# %% [markdown]
# ## Random brightness augmentation

# %%
brightness_datagen=image.ImageDataGenerator(brightness_range=[0.2,1.0])
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <tensorflow.python.keras.preprocessing.image.NumpyArrayIterator object at 0x000001E519BDBFD0>

# %% [markdown]
# ## Random zoom augmentation

# %%
zoom_datagen=image.ImageDataGenerator(zoom_range=[0.5,1.0])
it=shift_datagen.flow(samples,batch_size=1)
print(it)
for i in range(9):
    plt.subplot(330+1+i)
    batch=it.next()
    img=batch[0].astype('uint8')
    plt.imshow(img)
plt.show()
# Out:
# <tensorflow.python.keras.preprocessing.image.NumpyArrayIterator object at 0x000001E51B3484F0>
